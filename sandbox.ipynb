# %%
from typing import Any, Dict, Optional
from expedia.client import ExpediaClient, ExpediaAPIError

def fetch_amenities(
    client: ExpediaClient,
    *,
    language: str = "en-US",
    supply_source: Optional[str] = None,
    page_size: int = 200,
    cursor: Optional[str] = None,
) -> Dict[str, Any]:
    """
    Call GET /references/amenities and return the parsed JSON payload.

    Args:
        client: An authenticated ExpediaClient instance.
        language: Locale for amenity names (Expedia defaults to en-US).
        supply_source: Optional supply filter (e.g., "expedia" or "vrbo").
        page_size: Number of amenities per page (1..200 per EPS docs).
        cursor: Cursor token for pagination.

    Returns:
        Dict[str, Any]: Response body straight from the API.

    Raises:
        ExpediaAPIError: Surface any HTTP or payload issues from the client.
    """
    params: Dict[str, Any] = {"language": language, "page_size": page_size}
    if supply_source:
        params["supply_source"] = supply_source
    if cursor:
        params["cursor"] = cursor

    return client._request(
        "get",
        "v3/references/amenities",
        params=params,
    )

client = ExpediaClient.from_env()
amenities_ref = fetch_amenities(client)

# %%
amenities_ref
# Out:
# {'1073744371': {'id': '1073744371', 'name': 'Air hockey', 'has_value': False},
#  '1073745340': {'id': '1073745340',
#   'name': 'Single-level property',
#   'has_value': False},
#  '1073745341': {'id': '1073745341',
#   'name': 'Number of stairs to reach property',
#   'has_value': True},
#  '1073744373': {'id': '1073744373', 'name': 'Garage', 'has_value': False},
#  '1073744252': {'id': '1073744252',
#   'name': 'Renewable energy source - solar',
#   'has_value': False},
#  '1073744372': {'id': '1073744372', 'name': 'Carport', 'has_value': False},
#  '1073745460': {'id': '1073745460',
#   'name': 'Express theme park tickets',
#   'has_value': False},
#  '1073744375': {'id': '1073744375', 'name': 'Golf cart', 'has_value': False},
#  '1073745344': {'id': '1073745344',
#   'name': 'Tile flooring in public areas',
#   'has_value': False},
#  '1073744254': {'id': '1073744254',
#   'name': 'Renewable energy source - wind',
#   'has_value': False},
#  '1073744374': {'id': '1073744374',
#   'name': 'Gated community',
#   'has_value': False},
#  '1073745345': {'id': '1073745345',
#   'name': 'Hardwood flooring in public areas',
#   'has_value': False},
#  '1073744253': {'id': '1073744253',
#   'name': 'Renewable energy source - geothermal',
#   'has_value': False},
#  '1073744377': {'id': '1073744377',
#   'name': 'Optional golf privileges',
#   'has_value': False},
#  '1073745342': {'id': '1073745342',
#   'name': 'Smooth flooring in public areas',
#   'has_value': False},
#  '1073744256': {'id': '1073744256',
#   'name': 'Grey water recycling system',
#   'has_value': False},
#  '3761': {'id': '3761',
#   'name': 'Parking (limited spaces)',
#   'has_value': False},
#  '1073744376': {'id': '1073744376',
#   'name': 'Golf clubs (equipment)',
#   'has_value': False},
#  '1073745343': {'id': '1073745343',
#   'name': 'Thin carpet in public areas',
#   'has_value': False},
#  '1073744255': {'id': '1073744255',
#   'name': 'Eco-friendly cleaning products used',
#   'has_value': False},
#  '1073744379': {'id': '1073744379',
#   'name': 'Outdoor furniture',
#   'has_value': False},
#  '1073745348': {'id': '1073745348',
#   'name': 'Area rugs in public areas',
#   'has_value': False},
#  '1073744378': {'id': '1073744378',
#   'name': 'Outdoor entertainment area',
#   'has_value': False},
#  '1073745349': {'id': '1073745349',
#   'name': 'Front entrance ramp',
#   'has_value': False},
#  '1073745346': {'id': '1073745346',
#   'name': 'Gravel flooring in public areas',
#   'has_value': False},
#  '1073745347': {'id': '1073745347',
#   'name': 'Cobblestone flooring in public areas',
#   'has_value': False},
#  '2425': {'id': '2425',
#   'name': 'Braille or raised signage',
#   'has_value': False},
#  '2424': {'id': '2424',
#   'name': 'Assistive listening devices available',
#   'has_value': False},
#  '2422': {'id': '2422',
#   'name': 'Wheelchair accessible parking',
#   'has_value': False},
#  '2783': {'id': '2783', 'name': 'RV, bus, truck parking', 'has_value': False},
#  '1073743392': {'id': '1073743392',
#   'name': 'Free WiFi (limited) time',
#   'has_value': True},
#  '1073744241': {'id': '1073744241',
#   'name': 'Eco-friendly toiletries',
#   'has_value': False},
#  '1073743394': {'id': '1073743394',
#   'name': 'Free WiFi (limited) device count',
#   'has_value': True},
#  '1073744120': {'id': '1073744120',
#   'name': 'Exercise/lap pool',
#   'has_value': False},
#  '1073744240': {'id': '1073744240',
#   'name': 'Eco-friendly cleaning products provided',
#   'has_value': False},
#  '1073743393': {'id': '1073743393',
#   'name': 'Free WiFi (limited) duration',
#   'has_value': True},
#  '1073744122': {'id': '1073744122',
#   'name': 'Shared/communal pool',
#   'has_value': False},
#  '1073744243': {'id': '1073744243', 'name': 'Recycling', 'has_value': False},
#  '1073745333': {'id': '1073745333',
#   'name': 'Accessible airport shuttle',
#   'has_value': False},
#  '1073744242': {'id': '1073744242',
#   'name': 'LED light bulbs',
#   'has_value': False},
#  '1073744121': {'id': '1073744121', 'name': 'Heated pool', 'has_value': False},
#  '1073745334': {'id': '1073745334',
#   'name': 'No accessible airport shuttle',
#   'has_value': False},
#  '1073743395': {'id': '1073743395',
#   'name': 'Limited WiFi (surcharge) device count',
#   'has_value': True},
#  '1073745331': {'id': '1073745331',
#   'name': 'Accessible shuttle',
#   'has_value': False},
#  '1073744245': {'id': '1073744245',
#   'name': 'Living plant wall',
#   'has_value': False},
#  '1073745332': {'id': '1073745332',
#   'name': 'No accessible shuttle',
#   'has_value': False},
#  '1073744244': {'id': '1073744244',
#   'name': 'Reusable coffee/tea filters',
#   'has_value': False},
#  '1073745337': {'id': '1073745337',
#   'name': 'Accessible train station shuttle',
#   'has_value': False},
#  '1073745458': {'id': '1073745458',
#   'name': 'After-hours theme park access',
#   'has_value': False},
#  '1073745338': {'id': '1073745338',
#   'name': 'No accessible train station shuttle',
#   'has_value': False},
#  '1073745459': {'id': '1073745459',
#   'name': 'Theme park character encounters',
#   'has_value': False},
#  '1073745335': {'id': '1073745335',
#   'name': 'Accessible bus station shuttle',
#   'has_value': False},
#  '1073745336': {'id': '1073745336',
#   'name': 'No accessible bus station shuttle',
#   'has_value': False},
#  '1073745457': {'id': '1073745457',
#   'name': 'Early theme park entry',
#   'has_value': False},
#  '1073745339': {'id': '1073745339',
#   'name': 'Number of accessible parking spaces',
#   'has_value': True},
#  '2798': {'id': '2798', 'name': 'Long-term parking', 'has_value': False},
#  '6': {'id': '6', 'name': 'Babysitting or childcare', 'has_value': False},
#  '8': {'id': '8', 'name': 'Elevator', 'has_value': False},
#  '9': {'id': '9', 'name': 'Fitness facilities', 'has_value': False},
#  '1073743381': {'id': '1073743381', 'name': 'Stereo', 'has_value': False},
#  '1073743383': {'id': '1073743383', 'name': 'Games', 'has_value': False},
#  '1073743382': {'id': '1073743382', 'name': 'Books', 'has_value': False},
#  '1073744111': {'id': '1073744111',
#   'name': 'Banquet hall',
#   'has_value': False},
#  '1073743385': {'id': '1073743385',
#   'name': 'Infant/toddler toys',
#   'has_value': False},
#  '1073743384': {'id': '1073743384',
#   'name': 'Video library',
#   'has_value': False},
#  '1073744110': {'id': '1073744110', 'name': 'Ballroom', 'has_value': False},
#  '1073744113': {'id': '1073744113',
#   'name': 'Vending machine',
#   'has_value': False},
#  '1073745320': {'id': '1073745320',
#   'name': 'Paddleboating nearby',
#   'has_value': False},
#  '1073743387': {'id': '1073743387',
#   'name': 'Music library',
#   'has_value': False},
#  '1073744234': {'id': '1073744234',
#   'name': 'Firewood (free)',
#   'has_value': False},
#  '1073743386': {'id': '1073743386',
#   'name': 'Table tennis',
#   'has_value': False},
#  '1073744233': {'id': '1073744233', 'name': 'Dock', 'has_value': False},
#  '1073744112': {'id': '1073744112',
#   'name': 'Reception hall',
#   'has_value': False},
#  '1073744236': {'id': '1073744236',
#   'name': 'Street parking',
#   'has_value': False},
#  '1073744115': {'id': '1073744115',
#   'name': 'Infinity pool',
#   'has_value': False},
#  '1073744235': {'id': '1073744235',
#   'name': 'Fully fenced',
#   'has_value': False},
#  '1073743388': {'id': '1073743388', 'name': 'Foosball', 'has_value': False},
#  '1073744114': {'id': '1073744114',
#   'name': 'Natural pool',
#   'has_value': False},
#  '1073744117': {'id': '1073744117',
#   'name': 'Indoor/outdoor pool',
#   'has_value': False},
#  '1073745567': {'id': '1073745567',
#   'name': 'Afternoon tea',
#   'has_value': False},
#  '1073744119': {'id': '1073744119',
#   'name': 'Rooftop pool',
#   'has_value': False},
#  '1073744239': {'id': '1073744239', 'name': 'Composting', 'has_value': False},
#  '1073744118': {'id': '1073744118',
#   'name': 'Pool waterfall',
#   'has_value': False},
#  '4502': {'id': '4502', 'name': 'Boat tours nearby', 'has_value': False},
#  '4503': {'id': '4503', 'name': 'Boat tours on site', 'has_value': False},
#  '3778': {'id': '3778', 'name': 'Free bicycles on site', 'has_value': False},
#  '1073745311': {'id': '1073745311',
#   'name': 'Water-efficient toilets only',
#   'has_value': False},
#  '1073745312': {'id': '1073745312',
#   'name': 'Water dispenser use by guests actively encouraged',
#   'has_value': False},
#  '1073744462': {'id': '1073744462',
#   'name': 'Free Korean breakfast',
#   'has_value': False},
#  '1073744465': {'id': '1073744465',
#   'name': 'Free Taiwanese breakfast',
#   'has_value': False},
#  '1073745310': {'id': '1073745310',
#   'name': 'Water-efficient showers only',
#   'has_value': False},
#  '1073744464': {'id': '1073744464',
#   'name': 'Free Japanese breakfast',
#   'has_value': False},
#  '1073745436': {'id': '1073745436',
#   'name': 'Indoor padel courts -',
#   'has_value': True},
#  '1073745437': {'id': '1073745437',
#   'name': 'Outdoor padel courts -',
#   'has_value': True},
#  '1073744466': {'id': '1073744466',
#   'name': 'Free Cantonese breakfast',
#   'has_value': False},
#  '1073745313': {'id': '1073745313',
#   'name': 'Canoeing nearby',
#   'has_value': False},
#  '1073745314': {'id': '1073745314', 'name': 'Pool toys', 'has_value': False},
#  '1073744226': {'id': '1073744226', 'name': 'Trampoline', 'has_value': False},
#  '1073745435': {'id': '1073745435',
#   'name': 'Padel court on site',
#   'has_value': False},
#  '1073744108': {'id': '1073744108',
#   'name': 'Hunting on site',
#   'has_value': False},
#  '1073744107': {'id': '1073744107',
#   'name': 'Archery on site',
#   'has_value': False},
#  '1073745318': {'id': '1073745318',
#   'name': 'Duty-free shopping',
#   'has_value': False},
#  '1073744109': {'id': '1073744109',
#   'name': 'Ropes course on site',
#   'has_value': False},
#  '4514': {'id': '4514', 'name': 'Terrace', 'has_value': False},
#  '3788': {'id': '3788',
#   'name': 'Access to nearby indoor pool',
#   'has_value': False},
#  '3789': {'id': '3789',
#   'name': 'Access to nearby outdoor pool',
#   'has_value': False},
#  '1073745300': {'id': '1073745300',
#   'name': 'Comprehensive recycling policy',
#   'has_value': False},
#  '1073744572': {'id': '1073744572',
#   'name': 'Hosted evening meal (reserve)',
#   'has_value': False},
#  '1073745301': {'id': '1073745301',
#   'name': 'Bulk dispenser for toiletries',
#   'has_value': False},
#  '4650': {'id': '4650', 'name': 'Free full breakfast', 'has_value': False},
#  '1073744451': {'id': '1073744451', 'name': 'Sportsbook', 'has_value': False},
#  '1073745304': {'id': '1073745304',
#   'name': 'Biodegradable/compostable stirrers',
#   'has_value': False},
#  '2353': {'id': '2353', 'name': 'Airport transportation', 'has_value': False},
#  '2352': {'id': '2352', 'name': 'Pool umbrellas', 'has_value': False},
#  '2594': {'id': '2594', 'name': 'Free reception', 'has_value': False},
#  '1073745305': {'id': '1073745305',
#   'name': 'No single-use plastic straws',
#   'has_value': False},
#  '2593': {'id': '2593',
#   'name': 'Number of meeting rooms -',
#   'has_value': True},
#  '1073745302': {'id': '1073745302',
#   'name': 'No single-use plastic soda bottles',
#   'has_value': False},
#  '2592': {'id': '2592',
#   'name': 'Conference space size (meters) -',
#   'has_value': True},
#  '1073745303': {'id': '1073745303',
#   'name': 'No single-use plastic stirrers',
#   'has_value': False},
#  '1073745308': {'id': '1073745308',
#   'name': 'Reusable cups only',
#   'has_value': False},
#  '1073745309': {'id': '1073745309',
#   'name': 'Reusable tableware only',
#   'has_value': False},
#  '1073745306': {'id': '1073745306',
#   'name': 'Biodegradable/compostable straws',
#   'has_value': False},
#  '1073745307': {'id': '1073745307',
#   'name': 'No single-use plastic water bottles',
#   'has_value': False},
#  '2349': {'id': '2349',
#   'name': 'Designated smoking areas',
#   'has_value': False},
#  '2101': {'id': '2101',
#   'name': 'Internet access - wireless',
#   'has_value': False},
#  '4400': {'id': '4400', 'name': 'Sledding on site', 'has_value': False},
#  '4401': {'id': '4401', 'name': 'Sledding nearby', 'has_value': False},
#  '3799': {'id': '3799', 'name': 'Fitness classes on site', 'has_value': False},
#  '4646': {'id': '4646',
#   'name': 'Free continental breakfast',
#   'has_value': False},
#  '4404': {'id': '4404', 'name': 'Snow tubing on site', 'has_value': False},
#  '4647': {'id': '4647', 'name': 'Free buffet breakfast', 'has_value': False},
#  '4405': {'id': '4405', 'name': 'Snow tubing nearby', 'has_value': False},
#  '4648': {'id': '4648',
#   'name': 'Free cooked-to-order breakfast',
#   'has_value': False},
#  '4649': {'id': '4649', 'name': 'Free English breakfast', 'has_value': False},
#  '1073744560': {'id': '1073744560',
#   'name': 'Hosted evening meal',
#   'has_value': False},
#  '4421': {'id': '4421', 'name': 'Free ski shuttle', 'has_value': False},
#  '2001': {'id': '2001', 'name': 'Free breakfast', 'has_value': False},
#  '2364': {'id': '2364',
#   'name': 'Golf lessons available nearby',
#   'has_value': False},
#  '2362': {'id': '2362',
#   'name': 'Ski equipment rental shops nearby',
#   'has_value': False},
#  '2360': {'id': '2360',
#   'name': 'Ski lessons available nearby',
#   'has_value': False},
#  '2357': {'id': '2357', 'name': 'Ecotours nearby', 'has_value': False},
#  '2112': {'id': '2112', 'name': 'Casino', 'has_value': False},
#  '1073744430': {'id': '1073744430',
#   'name': 'Wheelchair accessible (may have limitations)',
#   'has_value': False},
#  '1073744795': {'id': '1073744795',
#   'name': 'Food and water bowls',
#   'has_value': False},
#  '4431': {'id': '4431',
#   'name': 'Direct access to private beach',
#   'has_value': False},
#  '4432': {'id': '4432', 'name': 'Beach umbrellas', 'has_value': False},
#  '1073744797': {'id': '1073744797',
#   'name': 'Dog exercise area',
#   'has_value': False},
#  '1073744796': {'id': '1073744796', 'name': 'Litter box', 'has_value': False},
#  '1073745525': {'id': '1073745525', 'name': 'Splash pad', 'has_value': False},
#  '2010': {'id': '2010', 'name': 'Nightclub', 'has_value': False},
#  '2131': {'id': '2131', 'name': 'Meeting rooms', 'has_value': False},
#  '1073744799': {'id': '1073744799',
#   'name': 'Pet grooming services',
#   'has_value': False},
#  '1073744798': {'id': '1073744798',
#   'name': 'Pet-sitting services',
#   'has_value': False},
#  '1073744314': {'id': '1073744314',
#   'name': 'Lot hours - start time',
#   'has_value': True},
#  '1073745526': {'id': '1073745526',
#   'name': 'Inflatable splash pad',
#   'has_value': False},
#  '2129': {'id': '2129', 'name': 'Spa treatment room(s)', 'has_value': False},
#  '2008': {'id': '2008', 'name': 'Health club', 'has_value': False},
#  '2128': {'id': '2128', 'name': 'Marina on site', 'has_value': False},
#  '2125': {'id': '2125',
#   'name': 'Internet access in public areas - high speed',
#   'has_value': False},
#  '2123': {'id': '2123', 'name': 'Full-service spa', 'has_value': False},
#  '4422': {'id': '4422', 'name': 'Ski shuttle (surcharge)', 'has_value': False},
#  '4423': {'id': '4423', 'name': 'Ski passes available', 'has_value': False},
#  '4428': {'id': '4428', 'name': 'Free beach shuttle', 'has_value': False},
#  '4429': {'id': '4429',
#   'name': 'Beach shuttle (surcharge)',
#   'has_value': False},
#  '2386': {'id': '2386',
#   'name': 'Grocery/convenience store',
#   'has_value': False},
#  '1073744302': {'id': '1073744302',
#   'name': 'Bus station shuttle (surcharge)',
#   'has_value': False},
#  '2385': {'id': '2385', 'name': 'Billiards or pool table', 'has_value': False},
#  '1073744422': {'id': '1073744422',
#   'name': 'Coin laundry on site',
#   'has_value': False},
#  '1073744301': {'id': '1073744301',
#   'name': 'Free bus station shuttle',
#   'has_value': False},
#  '1073744304': {'id': '1073744304',
#   'name': 'Kaiseki meal',
#   'has_value': False},
#  '1073744303': {'id': '1073744303', 'name': 'Tea service', 'has_value': False},
#  '1073744305': {'id': '1073744305',
#   'name': 'Genkan (entryway)',
#   'has_value': False},
#  '2017': {'id': '2017', 'name': 'Spa services on site', 'has_value': False},
#  '2138': {'id': '2138', 'name': 'Outdoor seasonal pool', 'has_value': False},
#  '2137': {'id': '2137', 'name': 'Smoke-free property', 'has_value': False},
#  '2016': {'id': '2016',
#   'name': 'Safe-deposit box at front desk',
#   'has_value': False},
#  '2135': {'id': '2135', 'name': 'Sauna', 'has_value': False},
#  '2014': {'id': '2014', 'name': "Children's pool", 'has_value': False},
#  '2134': {'id': '2134', 'name': 'Steam room', 'has_value': False},
#  '4433': {'id': '4433', 'name': 'Free beach cabanas', 'has_value': False},
#  '4434': {'id': '4434',
#   'name': 'Beach cabanas (surcharge)',
#   'has_value': False},
#  '4435': {'id': '4435',
#   'name': 'Pool cabanas (surcharge)',
#   'has_value': False},
#  '4436': {'id': '4436', 'name': 'Free pool cabanas', 'has_value': False},
#  '4437': {'id': '4437', 'name': 'Beach sun loungers', 'has_value': False},
#  '4438': {'id': '4438', 'name': 'Pool sun loungers', 'has_value': False},
#  '1073744098': {'id': '1073744098',
#   'name': 'Game/wildlife walks nearby',
#   'has_value': False},
#  '4450': {'id': '4450', 'name': 'Free long-term parking', 'has_value': False},
#  '1073744097': {'id': '1073744097',
#   'name': 'Game/wildlife walks on site',
#   'has_value': False},
#  '4451': {'id': '4451',
#   'name': 'Long-term parking (surcharge)',
#   'has_value': False},
#  '1073744099': {'id': '1073744099',
#   'name': 'Proposal/romance packages available',
#   'has_value': False},
#  '4452': {'id': '4452',
#   'name': 'Free RV, bus, truck parking',
#   'has_value': False},
#  '4695': {'id': '4695',
#   'name': 'Babysitting or childcare (free)',
#   'has_value': False},
#  '4453': {'id': '4453',
#   'name': 'RV, bus, truck parking (surcharge)',
#   'has_value': False},
#  '4696': {'id': '4696',
#   'name': 'Babysitting or childcare (surcharge)',
#   'has_value': False},
#  '4454': {'id': '4454', 'name': 'Free parking nearby', 'has_value': False},
#  '2393': {'id': '2393',
#   'name': 'Wired internet access - surcharge',
#   'has_value': False},
#  '2392': {'id': '2392', 'name': 'Free wired internet', 'has_value': False},
#  '2391': {'id': '2391', 'name': 'WiFi (surcharge)', 'has_value': False},
#  '2390': {'id': '2390', 'name': 'Free WiFi', 'has_value': False},
#  '1073742906': {'id': '1073742906',
#   'name': 'Parking onsite',
#   'has_value': False},
#  '1073742907': {'id': '1073742907',
#   'name': 'Internet access',
#   'has_value': False},
#  '2146': {'id': '2146', 'name': 'Snowboarding nearby', 'has_value': False},
#  '2387': {'id': '2387', 'name': 'Tours/ticket assistance', 'has_value': False},
#  '1073744092': {'id': '1073744092',
#   'name': 'Birdwatching nearby',
#   'has_value': False},
#  '1073744091': {'id': '1073744091',
#   'name': 'Birdwatching on site',
#   'has_value': False},
#  '1073744094': {'id': '1073744094',
#   'name': 'Casino floor size square meters -',
#   'has_value': True},
#  '1073744085': {'id': '1073744085',
#   'name': 'Nature reserve',
#   'has_value': False},
#  '1073745296': {'id': '1073745296',
#   'name': "All property's electricity comes from renewable sources",
#   'has_value': False},
#  '1073745297': {'id': '1073745297',
#   'name': 'Comprehensive food waste policy',
#   'has_value': False},
#  '1073744084': {'id': '1073744084',
#   'name': 'Luxury tents',
#   'has_value': False},
#  '1073745294': {'id': '1073745294',
#   'name': 'Energy-saving switches',
#   'has_value': False},
#  '1073744087': {'id': '1073744087',
#   'name': 'Vegetable garden',
#   'has_value': False},
#  '1073745295': {'id': '1073745295',
#   'name': 'At least 80% of all lighting comes from LEDs',
#   'has_value': False},
#  '1073744086': {'id': '1073744086',
#   'name': 'Farming classes',
#   'has_value': False},
#  '1073745298': {'id': '1073745298',
#   'name': 'Vegan menu options available',
#   'has_value': False},
#  '1073745299': {'id': '1073745299',
#   'name': 'Vegetarian menu options available',
#   'has_value': False},
#  '3376': {'id': '3376', 'name': 'Outdoor tennis courts -', 'has_value': True},
#  '2043': {'id': '2043', 'name': 'Multilingual staff', 'has_value': False},
#  '3374': {'id': '3374', 'name': 'Indoor tennis courts -', 'has_value': True},
#  '3372': {'id': '3372', 'name': 'Conference center', 'has_value': False},
#  '401': {'id': '401', 'name': 'Wood stove', 'has_value': False},
#  '403': {'id': '403', 'name': 'Rafting nearby', 'has_value': False},
#  '4697': {'id': '4697', 'name': "Children's club (free)", 'has_value': False},
#  '4455': {'id': '4455',
#   'name': 'Offsite parking discounted rates available',
#   'has_value': False},
#  '4698': {'id': '4698',
#   'name': "Children's club (surcharge)",
#   'has_value': False},
#  '4456': {'id': '4456',
#   'name': 'Offsite parking reservations required',
#   'has_value': False},
#  '4699': {'id': '4699',
#   'name': 'Supervised childcare/activities (free)',
#   'has_value': False},
#  '1073745292': {'id': '1073745292',
#   'name': 'Double-glazing on all windows',
#   'has_value': False},
#  '1073745293': {'id': '1073745293',
#   'name': 'Locally-sourced food on site (80% or more)',
#   'has_value': False},
#  '1073745290': {'id': '1073745290',
#   'name': 'Sustainability/community reinvestment (10% revenue or more)',
#   'has_value': False},
#  '1073744083': {'id': '1073744083',
#   'name': 'Motorcycle parking only',
#   'has_value': False},
#  '1073745291': {'id': '1073745291',
#   'name': 'Guest education on local ecosystems and culture',
#   'has_value': False},
#  '1073744074': {'id': '1073744074',
#   'name': 'Wine release events',
#   'has_value': False},
#  '1073745285': {'id': '1073745285',
#   'name': 'Rooftop garden',
#   'has_value': False},
#  '1073744073': {'id': '1073744073',
#   'name': 'Tasting room',
#   'has_value': False},
#  '1073745286': {'id': '1073745286',
#   'name': 'Annual carbon offsets',
#   'has_value': False},
#  '1073744076': {'id': '1073744076',
#   'name': 'Public winery tours',
#   'has_value': False},
#  '1073744075': {'id': '1073744075',
#   'name': 'Private winery tours',
#   'has_value': False},
#  '1073745284': {'id': '1073745284',
#   'name': 'Organic food',
#   'has_value': False},
#  '1073745289': {'id': '1073745289',
#   'name': 'Showcase for local artists',
#   'has_value': False},
#  '4111': {'id': '4111',
#   'name': 'Free grocery shopping service',
#   'has_value': False},
#  '1073745287': {'id': '1073745287',
#   'name': 'Humane animal treatment',
#   'has_value': False},
#  '1073745288': {'id': '1073745288',
#   'name': 'Locally-owned & organized tours & activities',
#   'has_value': False},
#  '2177': {'id': '2177', 'name': 'Express check-in', 'has_value': False},
#  '2049': {'id': '2049', 'name': 'Picnic area', 'has_value': False},
#  '2048': {'id': '2048',
#   'name': 'Free use of nearby fitness center',
#   'has_value': False},
#  '2047': {'id': '2047',
#   'name': 'Free newspapers in lobby',
#   'has_value': False},
#  '2167': {'id': '2167', 'name': 'Wedding services', 'has_value': False},
#  '4467': {'id': '4467', 'name': 'Beach towels', 'has_value': False},
#  '4468': {'id': '4468',
#   'name': '24-hour fitness facilities',
#   'has_value': False},
#  '1073744070': {'id': '1073744070',
#   'name': 'Shopping mall on site',
#   'has_value': False},
#  '1073744072': {'id': '1073744072', 'name': 'Vineyard', 'has_value': False},
#  '1073744071': {'id': '1073744071',
#   'name': 'Art gallery on site',
#   'has_value': False},
#  '1073744063': {'id': '1073744063', 'name': 'Pro shop', 'has_value': False},
#  '1073744062': {'id': '1073744062',
#   'name': 'Golf lessons with a pro',
#   'has_value': False},
#  '1073744065': {'id': '1073744065', 'name': 'Golf caddy', 'has_value': False},
#  '1073744064': {'id': '1073744064', 'name': 'Clubhouse', 'has_value': False},
#  '1073744067': {'id': '1073744067',
#   'name': 'Private picnics',
#   'has_value': False},
#  '1073744066': {'id': '1073744066',
#   'name': 'Couples/private dining',
#   'has_value': False},
#  '1073744069': {'id': '1073744069',
#   'name': 'Designer stores on site',
#   'has_value': False},
#  '4003': {'id': '4003', 'name': 'Luggage storage', 'has_value': False},
#  '2067': {'id': '2067', 'name': 'Express check-out', 'has_value': False},
#  '2066': {'id': '2066', 'name': 'Porter/bellhop', 'has_value': False},
#  '2186': {'id': '2186', 'name': "Children's club", 'has_value': False},
#  '2065': {'id': '2065', 'name': 'Business center', 'has_value': False},
#  '2064': {'id': '2064',
#   'name': 'Front desk (limited hours)',
#   'has_value': False},
#  '2063': {'id': '2063', 'name': '24-hour front desk', 'has_value': False},
#  '3269': {'id': '3269',
#   'name': 'Designated smoking areas (fines apply)',
#   'has_value': False},
#  '2178': {'id': '2178',
#   'name': 'Use of nearby fitness center (discount)',
#   'has_value': False},
#  '2070': {'id': '2070',
#   'name': 'Dry cleaning/laundry service',
#   'has_value': False},
#  '1073745263': {'id': '1073745263',
#   'name': 'Paddleboard on site',
#   'has_value': False},
#  '4491': {'id': '4491',
#   'name': 'Beach volleyball on site',
#   'has_value': False},
#  '1073744293': {'id': '1073744293',
#   'name': 'Distance from property (meters)',
#   'has_value': True},
#  '1073745264': {'id': '1073745264',
#   'name': 'Bodyboard on site',
#   'has_value': False},
#  '1073745261': {'id': '1073745261', 'name': 'Gas grill', 'has_value': False},
#  '1073744296': {'id': '1073744296',
#   'name': 'Lot hours - 24 hours',
#   'has_value': False},
#  '1073745262': {'id': '1073745262',
#   'name': 'Charcoal grill',
#   'has_value': False},
#  '4010': {'id': '4010',
#   'name': 'Train station pickup (surcharge)',
#   'has_value': False},
#  '1073744295': {'id': '1073744295',
#   'name': 'Distance from property (miles)',
#   'has_value': True},
#  '4497': {'id': '4497', 'name': 'Beach yoga on site', 'has_value': False},
#  '1073745265': {'id': '1073745265',
#   'name': 'Vegetarian breakfast available',
#   'has_value': False},
#  '5103': {'id': '5103', 'name': 'Ziplining nearby', 'has_value': False},
#  '1073744299': {'id': '1073744299',
#   'name': 'Lot hours - end time',
#   'has_value': True},
#  '2074': {'id': '2074', 'name': 'Swimming pool', 'has_value': False},
#  '2072': {'id': '2072',
#   'name': 'Limo or town car service available',
#   'has_value': False},
#  '2189': {'id': '2189',
#   'name': 'Expedia Local Expert concierge',
#   'has_value': False},
#  '4004': {'id': '4004',
#   'name': 'Free airport transportation - pickup',
#   'has_value': False},
#  '317': {'id': '317', 'name': 'Fireplace in lobby', 'has_value': False},
#  '4005': {'id': '4005',
#   'name': 'Free airport transportation - drop-off',
#   'has_value': False},
#  '4006': {'id': '4006',
#   'name': 'Airport transportation - pickup (surcharge)',
#   'has_value': False},
#  '4007': {'id': '4007',
#   'name': 'Airport transportation - drop-off (surcharge)',
#   'has_value': False},
#  '1073744290': {'id': '1073744290',
#   'name': 'Distance from property (km)',
#   'has_value': True},
#  '1073745494': {'id': '1073745494',
#   'name': 'No laundry facility',
#   'has_value': False},
#  '2080': {'id': '2080', 'name': 'On private beach', 'has_value': False},
#  '1073745492': {'id': '1073745492',
#   'name': 'No fitness facility',
#   'has_value': False},
#  '1073745493': {'id': '1073745493',
#   'name': 'No television',
#   'has_value': False},
#  '1073745256': {'id': '1073745256', 'name': 'Stroller', 'has_value': False},
#  '4025': {'id': '4025', 'name': 'Winery attached', 'has_value': False},
#  '1073744288': {'id': '1073744288',
#   'name': 'Distance from property (ft)',
#   'has_value': True},
#  '2089': {'id': '2089', 'name': 'Snowmobiling nearby', 'has_value': False},
#  '2087': {'id': '2087', 'name': 'Parasailing nearby', 'has_value': False},
#  '2082': {'id': '2082', 'name': 'Ski-in/ski-out access', 'has_value': False},
#  '321': {'id': '321', 'name': 'Barbecue grill(s)', 'has_value': False},
#  '324': {'id': '324',
#   'name': 'Coffee/tea in common areas',
#   'has_value': False},
#  '5104': {'id': '5104', 'name': 'Ziplining on site', 'has_value': False},
#  '1073745490': {'id': '1073745490',
#   'name': 'No breakfast',
#   'has_value': False},
#  '1073744280': {'id': '1073744280',
#   'name': 'Secured parking',
#   'has_value': False},
#  '1073744272': {'id': '1073744272',
#   'name': 'Covered parking',
#   'has_value': False},
#  '2092': {'id': '2092', 'name': 'Snowshoeing nearby', 'has_value': False},
#  '1073744393': {'id': '1073744393',
#   'name': 'Canoe on site',
#   'has_value': False},
#  '1073745483': {'id': '1073745483',
#   'name': 'No airport shuttle',
#   'has_value': False},
#  '1073744392': {'id': '1073744392',
#   'name': 'Motor boating nearby',
#   'has_value': False},
#  '1073745242': {'id': '1073745242', 'name': 'Beach toys', 'has_value': False},
#  '1073744274': {'id': '1073744274',
#   'name': 'Secured parking',
#   'has_value': False},
#  '2090': {'id': '2090', 'name': 'Mountain biking nearby', 'has_value': False},
#  '1073745481': {'id': '1073745481',
#   'name': 'Outdoor pickleball courts -',
#   'has_value': True},
#  '1073744395': {'id': '1073744395',
#   'name': 'Fish cleaning table',
#   'has_value': False},
#  '1073744273': {'id': '1073744273',
#   'name': 'Uncovered parking',
#   'has_value': False},
#  '1073744394': {'id': '1073744394',
#   'name': 'Cycling nearby',
#   'has_value': False},
#  '1073745482': {'id': '1073745482',
#   'name': 'No wheelchair-accessible path',
#   'has_value': False},
#  '1073744397': {'id': '1073744397',
#   'name': 'Casino nearby',
#   'has_value': False},
#  '1073744276': {'id': '1073744276',
#   'name': 'Uncovered parking',
#   'has_value': False},
#  '1073744396': {'id': '1073744396',
#   'name': 'Fishing nearby',
#   'has_value': False},
#  '1073744275': {'id': '1073744275',
#   'name': 'Covered parking',
#   'has_value': False},
#  '1073745488': {'id': '1073745488', 'name': 'No WiFi', 'has_value': False},
#  '1073744278': {'id': '1073744278',
#   'name': 'Covered parking',
#   'has_value': False},
#  '1073744399': {'id': '1073744399',
#   'name': 'Hiking nearby',
#   'has_value': False},
#  '1073744398': {'id': '1073744398',
#   'name': 'Health or beauty spa nearby',
#   'has_value': False},
#  '5004': {'id': '5004', 'name': 'Hot springs on site', 'has_value': False},
#  '1073744277': {'id': '1073744277',
#   'name': 'Secured parking',
#   'has_value': False},
#  '1073744279': {'id': '1073744279',
#   'name': 'Uncovered parking',
#   'has_value': False},
#  '1073745489': {'id': '1073745489', 'name': 'No hot tub', 'has_value': False},
#  '2094': {'id': '2094', 'name': 'Windsurfing nearby', 'has_value': False},
#  '2093': {'id': '2093', 'name': 'Skydiving nearby', 'has_value': False},
#  '333': {'id': '333',
#   'name': 'Internet access in public areas - surcharge',
#   'has_value': False},
#  '1073745480': {'id': '1073745480',
#   'name': 'Indoor pickleball courts -',
#   'has_value': True},
#  '1073744391': {'id': '1073744391',
#   'name': 'Boat and paddles on site',
#   'has_value': False},
#  '1073744390': {'id': '1073744390',
#   'name': 'Boat on site',
#   'has_value': False},
#  '1073745351': {'id': '1073745351',
#   'name': 'Registration desk height (centimeters) -',
#   'has_value': True},
#  '1073745352': {'id': '1073745352',
#   'name': 'Elevator door width (inches) -',
#   'has_value': True},
#  '1073744381': {'id': '1073744381',
#   'name': 'Off-street parking',
#   'has_value': False},
#  '1073744384': {'id': '1073744384',
#   'name': 'Walkway to water',
#   'has_value': False},
#  '1073744383': {'id': '1073744383', 'name': 'Telescope', 'has_value': False},
#  '1073745350': {'id': '1073745350',
#   'name': 'Registration desk height (inches) -',
#   'has_value': True},
#  '1073744141': {'id': '1073744141',
#   'name': 'Free self-serve breakfast',
#   'has_value': False},
#  '1073745355': {'id': '1073745355',
#   'name': 'Hallway handrail height (centimeters) -',
#   'has_value': True},
#  '1073745356': {'id': '1073745356',
#   'name': 'Stairwell handrail height (inches) -',
#   'has_value': True},
#  '1073744264': {'id': '1073744264',
#   'name': 'Japanese garden',
#   'has_value': False},
#  '1073744388': {'id': '1073744388',
#   'name': "Children's toys",
#   'has_value': False},
#  '1073745353': {'id': '1073745353',
#   'name': 'Elevator door width (centimeters) -',
#   'has_value': True},
#  '5015': {'id': '5015', 'name': 'Private beach nearby', 'has_value': False},
#  '1073744387': {'id': '1073744387',
#   'name': "Children's games",
#   'has_value': False},
#  '1073745354': {'id': '1073745354',
#   'name': 'Hallway handrail height (inches) -',
#   'has_value': True},
#  '1073744389': {'id': '1073744389',
#   'name': 'Basketball nearby',
#   'has_value': False},
#  '1073745357': {'id': '1073745357',
#   'name': 'Stairwell handrail height (centimeters) -',
#   'has_value': True},
#  '1073745478': {'id': '1073745478',
#   'name': 'Cooking classes on site',
#   'has_value': False},
#  '1073745479': {'id': '1073745479',
#   'name': 'Pickleball court on site',
#   'has_value': False},
#  '102': {'id': '102', 'name': 'Golfing nearby', 'has_value': False},
#  '103': {'id': '103', 'name': 'Snorkeling nearby', 'has_value': False},
#  '347': {'id': '347',
#   'name': 'Hiking/biking trails nearby',
#   'has_value': False},
#  '106': {'id': '106',
#   'name': 'Surfing/bodyboarding nearby',
#   'has_value': False},
#  '349': {'id': '349', 'name': 'Kayaking nearby', 'has_value': False},
#  '5005': {'id': '5005', 'name': 'Hot springs nearby', 'has_value': False},
#  '4174': {'id': '4174', 'name': 'Free water park access', 'has_value': False},
#  '4175': {'id': '4175',
#   'name': 'Water park access (surcharge)',
#   'has_value': False},
#  '5023': {'id': '5023', 'name': 'Game viewing on site', 'has_value': False},
#  '5024': {'id': '5024', 'name': 'Game viewing nearby', 'has_value': False},
#  '5025': {'id': '5025', 'name': 'Game drive on site', 'has_value': False},
#  '5026': {'id': '5026', 'name': 'Game drive nearby', 'has_value': False},
#  '1073743961': {'id': '1073743961',
#   'name': 'Number of slot machines -',
#   'has_value': True},
#  '1073744810': {'id': '1073744810',
#   'name': 'Bicycle cleaning area',
#   'has_value': False},
#  '1073743963': {'id': '1073743963',
#   'name': 'Number of VIP gaming rooms -',
#   'has_value': True},
#  '1073743962': {'id': '1073743962',
#   'name': 'Number of gaming tables -',
#   'has_value': True},
#  '1073743965': {'id': '1073743965', 'name': 'Bingo', 'has_value': False},
#  '1073744811': {'id': '1073744811',
#   'name': 'Bicycle equipment shop on site',
#   'has_value': False},
#  '1073743964': {'id': '1073743964', 'name': 'Pachinko', 'has_value': False},
#  '350': {'id': '350', 'name': 'Sailing nearby', 'has_value': False},
#  '1073744814': {'id': '1073744814',
#   'name': 'Electric bicycle charging station',
#   'has_value': False},
#  '351': {'id': '351', 'name': 'Scuba diving nearby', 'has_value': False},
#  '1073743966': {'id': '1073743966',
#   'name': 'Casino floor size square feet -',
#   'has_value': True},
#  '1073744805': {'id': '1073744805',
#   'name': 'Bicycle parking available',
#   'has_value': False},
#  '110': {'id': '110', 'name': 'Downhill skiing nearby', 'has_value': False},
#  '111': {'id': '111',
#   'name': 'Cross-country skiing nearby',
#   'has_value': False},
#  '1073744807': {'id': '1073744807',
#   'name': 'Bicycle tour information',
#   'has_value': False},
#  '354': {'id': '354', 'name': 'Ski storage', 'has_value': False},
#  '356': {'id': '356', 'name': 'Water skiing nearby', 'has_value': False},
#  '1073744809': {'id': '1073744809',
#   'name': 'Bicycle repair station',
#   'has_value': False},
#  '115': {'id': '115', 'name': 'Bicycle rentals nearby', 'has_value': False},
#  '1073744808': {'id': '1073744808',
#   'name': 'Shuttle for bicycles available',
#   'has_value': False},
#  '10': {'id': '10', 'name': 'Free airport transportation', 'has_value': False},
#  '1073743950': {'id': '1073743950', 'name': 'Firepit', 'has_value': False},
#  '1073743952': {'id': '1073743952',
#   'name': 'Shoji (room divider)',
#   'has_value': False},
#  '1073743951': {'id': '1073743951',
#   'name': 'Outdoor fireplace',
#   'has_value': False},
#  '1073743954': {'id': '1073743954',
#   'name': 'Concerts/live shows',
#   'has_value': False},
#  '1073743953': {'id': '1073743953',
#   'name': 'Engawa (sitting area)',
#   'has_value': False},
#  '1073744803': {'id': '1073744803',
#   'name': 'Secured bicycle storage',
#   'has_value': False},
#  '361': {'id': '361',
#   'name': 'Breakfast available (surcharge)',
#   'has_value': False},
#  '1073743956': {'id': '1073743956',
#   'name': 'Mosquito nets',
#   'has_value': False},
#  '1073743955': {'id': '1073743955',
#   'name': 'Evening entertainment',
#   'has_value': False},
#  '369': {'id': '369', 'name': 'Laundry facilities', 'has_value': False},
#  '5027': {'id': '5027', 'name': 'Safari on site', 'has_value': False},
#  '5028': {'id': '5028', 'name': 'Safari nearby', 'has_value': False},
#  '27': {'id': '27', 'name': 'Wheelchair accessible', 'has_value': False},
#  '1073744911': {'id': '1073744911',
#   'name': 'Pool access ramp on site',
#   'has_value': False},
#  '1073744910': {'id': '1073744910',
#   'name': 'Pool hoist on site',
#   'has_value': False},
#  '372': {'id': '372',
#   'name': 'Television in common areas',
#   'has_value': False},
#  '1073744904': {'id': '1073744904',
#   'name': 'No elevator (single level property)',
#   'has_value': False},
#  '375': {'id': '375', 'name': 'Arcade/game room', 'has_value': False},
#  '1073744906': {'id': '1073744906',
#   'name': 'Well-lit path to entrance',
#   'has_value': False},
#  '1073744905': {'id': '1073744905',
#   'name': 'Upper floors accessible by stairs only',
#   'has_value': False},
#  '378': {'id': '378', 'name': 'Garden', 'has_value': False},
#  '1073744908': {'id': '1073744908',
#   'name': 'Hospital bed available',
#   'has_value': False},
#  '1073744907': {'id': '1073744907',
#   'name': 'Stair-free path to entrance',
#   'has_value': False},
#  '1073744909': {'id': '1073744909',
#   'name': 'Portable hoist available',
#   'has_value': False},
#  '5054': {'id': '5054', 'name': '24-hour health club', 'has_value': False},
#  '6145': {'id': '6145', 'name': 'Free breakfast to go', 'has_value': False},
#  '38': {'id': '38',
#   'name': 'Supervised childcare/activities',
#   'has_value': False},
#  '381': {'id': '381',
#   'name': 'Personal motorized watercraft on site',
#   'has_value': False},
#  '383': {'id': '383',
#   'name': 'Scooter/moped rentals nearby',
#   'has_value': False},
#  '385': {'id': '385', 'name': 'Library', 'has_value': False},
#  '1073743926': {'id': '1073743926',
#   'name': 'Housekeeping on request',
#   'has_value': False},
#  '40': {'id': '40', 'name': 'Hair salon', 'has_value': False},
#  '41': {'id': '41', 'name': 'ATM/banking', 'has_value': False},
#  '43': {'id': '43', 'name': 'Concierge services', 'has_value': False},
#  '44': {'id': '44', 'name': 'Gift shops or newsstand', 'has_value': False},
#  '45': {'id': '45', 'name': 'Shopping on site', 'has_value': False},
#  '56': {'id': '56',
#   'name': 'Airport transportation (surcharge)',
#   'has_value': False},
#  '5096': {'id': '5096', 'name': 'Rock climbing nearby', 'has_value': False},
#  '5097': {'id': '5097', 'name': 'Rock climbing on site', 'has_value': False},
#  '5098': {'id': '5098',
#   'name': 'Cave exploring/spelunking nearby',
#   'has_value': False},
#  '5099': {'id': '5099',
#   'name': 'Cave exploring/spelunking on site',
#   'has_value': False},
#  '81': {'id': '81', 'name': 'Conference space', 'has_value': False},
#  '2819': {'id': '2819', 'name': 'Water park', 'has_value': False},
#  '2818': {'id': '2818', 'name': 'Waterslide', 'has_value': False},
#  '2817': {'id': '2817', 'name': 'Lazy river', 'has_value': False},
#  '1073745192': {'id': '1073745192',
#   'name': 'Fence around pool',
#   'has_value': False},
#  '1073744410': {'id': '1073744410',
#   'name': 'Ski lift privileges',
#   'has_value': False},
#  '1073744412': {'id': '1073744412',
#   'name': 'Snow sports gear',
#   'has_value': False},
#  '1073745502': {'id': '1073745502',
#   'name': 'Children eat free breakfast',
#   'has_value': True},
#  '1073744411': {'id': '1073744411',
#   'name': 'Optional ski privileges',
#   'has_value': False},
#  '1073744414': {'id': '1073744414',
#   'name': 'Water sports equipment',
#   'has_value': False},
#  '1073745500': {'id': '1073745500',
#   'name': 'No accessible parking',
#   'has_value': False},
#  '1073744898': {'id': '1073744898',
#   'name': 'Coworking spaces',
#   'has_value': False},
#  '1073744413': {'id': '1073744413',
#   'name': 'Swimming nearby',
#   'has_value': False},
#  '1073744416': {'id': '1073744416',
#   'name': 'Bicycle on site',
#   'has_value': False},
#  '1073744415': {'id': '1073744415',
#   'name': 'Water tubing nearby',
#   'has_value': False},
#  '3913': {'id': '3913', 'name': 'Number of bars/lounges -', 'has_value': True},
#  '2944': {'id': '2944',
#   'name': 'Free cruise terminal shuttle',
#   'has_value': False},
#  '1073744409': {'id': '1073744409',
#   'name': 'Sailboat on site',
#   'has_value': False},
#  '2822': {'id': '2822', 'name': 'Number of hot tubs -', 'has_value': True},
#  '3914': {'id': '3914',
#   'name': 'Number of poolside bars -',
#   'has_value': True},
#  '2943': {'id': '2943',
#   'name': 'Casino shuttle (surcharge)',
#   'has_value': False},
#  '1073744408': {'id': '1073744408',
#   'name': 'Pedal boat on site',
#   'has_value': False},
#  '1073744529': {'id': '1073744529',
#   'name': 'Beach club nearby (surcharge)',
#   'has_value': False},
#  '2821': {'id': '2821',
#   'name': 'Number of outdoor pools -',
#   'has_value': True},
#  '3915': {'id': '3915', 'name': 'Number of beach bars -', 'has_value': True},
#  '2942': {'id': '2942', 'name': 'Free casino shuttle', 'has_value': False},
#  '3916': {'id': '3916', 'name': 'Number of swim-up bars -', 'has_value': True},
#  '2820': {'id': '2820', 'name': 'Number of indoor pools -', 'has_value': True},
#  '2949': {'id': '2949',
#   'name': 'Shopping center shuttle (surcharge)',
#   'has_value': False},
#  '2948': {'id': '2948',
#   'name': 'Free shopping center shuttle',
#   'has_value': False},
#  '2947': {'id': '2947',
#   'name': 'Ferry terminal shuttle (surcharge)',
#   'has_value': False},
#  '2946': {'id': '2946',
#   'name': 'Free ferry terminal shuttle',
#   'has_value': False},
#  '2945': {'id': '2945',
#   'name': 'Cruise terminal shuttle (surcharge)',
#   'has_value': False},
#  '3912': {'id': '3912', 'name': 'Rooftop terrace', 'has_value': False},
#  '1073744760': {'id': '1073744760',
#   'name': 'Surf lessons - onsite',
#   'has_value': False},
#  '1073744641': {'id': '1073744641',
#   'name': 'Wheelchair-accessible lounge',
#   'has_value': False},
#  '1073744640': {'id': '1073744640',
#   'name': 'Wheelchair-accessible on-site restaurant',
#   'has_value': False},
#  '1073744761': {'id': '1073744761',
#   'name': 'Surf lessons - nearby',
#   'has_value': False},
#  '1073744401': {'id': '1073744401',
#   'name': 'Hunting nearby',
#   'has_value': False},
#  '1073744643': {'id': '1073744643',
#   'name': 'Sign language-capable staff',
#   'has_value': False},
#  '1073744642': {'id': '1073744642',
#   'name': 'Visual alarms in hallways',
#   'has_value': False},
#  '1073744400': {'id': '1073744400',
#   'name': 'Horse riding nearby',
#   'has_value': False},
#  '1073744645': {'id': '1073744645',
#   'name': 'Handrails in stairways',
#   'has_value': False},
#  '1073744403': {'id': '1073744403',
#   'name': 'Inflatable boat on site',
#   'has_value': False},
#  '1073744402': {'id': '1073744402',
#   'name': 'Ice skating nearby',
#   'has_value': False},
#  '1073743434': {'id': '1073743434',
#   'name': 'Free breakfast (local cuisine)',
#   'has_value': False},
#  '1073744644': {'id': '1073744644',
#   'name': 'Handrails in hallways',
#   'has_value': False},
#  '1073744405': {'id': '1073744405',
#   'name': 'Kayak on site',
#   'has_value': False},
#  '1073744526': {'id': '1073744526',
#   'name': 'Free beach club on site',
#   'has_value': False},
#  '1073743315': {'id': '1073743315',
#   'name': 'Electric car charging station',
#   'has_value': False},
#  '1073744404': {'id': '1073744404',
#   'name': 'Personal motor watercraft nearby',
#   'has_value': False},
#  '1073744646': {'id': '1073744646',
#   'name': 'Wheelchairs available on site',
#   'has_value': False},
#  '1073744407': {'id': '1073744407',
#   'name': 'Mountain climbing nearby',
#   'has_value': False},
#  '1073744528': {'id': '1073744528',
#   'name': 'Beach club on site (surcharge)',
#   'has_value': False},
#  '1073744406': {'id': '1073744406',
#   'name': 'Marina nearby',
#   'has_value': False},
#  '1073744527': {'id': '1073744527',
#   'name': 'Free beach club nearby',
#   'has_value': False},
#  '1073744639': {'id': '1073744639',
#   'name': 'Wheelchair-accessible meeting spaces/business center',
#   'has_value': False},
#  '3805': {'id': '3805', 'name': 'Bowling alley on site', 'has_value': False},
#  '3926': {'id': '3926',
#   'name': 'Segway rental/tour on site',
#   'has_value': False},
#  '3927': {'id': '3927',
#   'name': 'Segway rental/tour nearby',
#   'has_value': False},
#  '2951': {'id': '2951',
#   'name': 'Theme park shuttle (surcharge)',
#   'has_value': False},
#  '3807': {'id': '3807', 'name': 'Free bicycles nearby', 'has_value': False},
#  '3929': {'id': '3929',
#   'name': 'Number of coffee shops/cafes -',
#   'has_value': True},
#  '2950': {'id': '2950', 'name': 'Free theme park shuttle', 'has_value': False},
#  '3809': {'id': '3809', 'name': 'Ecotours on site', 'has_value': False},
#  '3800': {'id': '3800', 'name': 'Basketball on site', 'has_value': False},
#  '3801': {'id': '3801', 'name': 'Bicycle rentals on site', 'has_value': False},
#  '1073744630': {'id': '1073744630',
#   'name': 'Wheelchair-accessible concierge desk',
#   'has_value': False},
#  '1073744632': {'id': '1073744632',
#   'name': 'Wheelchair-accessible van parking',
#   'has_value': False},
#  '1073744631': {'id': '1073744631',
#   'name': 'Assistive listening devices in meeting rooms',
#   'has_value': False},
#  '1073744634': {'id': '1073744634',
#   'name': 'Wheelchair-accessible path to elevator',
#   'has_value': False},
#  '1073744633': {'id': '1073744633',
#   'name': 'Valet for wheelchair-equipped vehicle',
#   'has_value': False},
#  '1073744636': {'id': '1073744636',
#   'name': 'Wheelchair-accessible spa',
#   'has_value': False},
#  '1073743305': {'id': '1073743305',
#   'name': 'Free train station drop-off',
#   'has_value': False},
#  '1073743304': {'id': '1073743304', 'name': 'Karaoke', 'has_value': False},
#  '1073744635': {'id': '1073744635',
#   'name': 'Wheelchair-accessible registration desk',
#   'has_value': False},
#  '1073744638': {'id': '1073744638',
#   'name': 'Wheelchair-accessible fitness center',
#   'has_value': False},
#  '1073743549': {'id': '1073743549',
#   'name': '24-hour pool access',
#   'has_value': False},
#  '1073744637': {'id': '1073744637',
#   'name': 'Wheelchair-accessible pool',
#   'has_value': False},
#  '1073743306': {'id': '1073743306',
#   'name': 'Train station drop-off (surcharge)',
#   'has_value': False},
#  '1073744629': {'id': '1073744629',
#   'name': 'Wheelchair-accessible public washroom',
#   'has_value': False},
#  '3814': {'id': '3814', 'name': 'Golfing on site', 'has_value': False},
#  '3815': {'id': '3815',
#   'name': 'Helicopter/airplane tours on site',
#   'has_value': False},
#  '3816': {'id': '3816',
#   'name': 'Hiking/biking trails on site',
#   'has_value': False},
#  '3817': {'id': '3817',
#   'name': 'Horse riding/rental on site',
#   'has_value': False},
#  '3819': {'id': '3819', 'name': 'Ice skating on site', 'has_value': False},
#  '3810': {'id': '3810', 'name': 'Fishing on site', 'has_value': False},
#  '3811': {'id': '3811',
#   'name': 'Golf driving range on site',
#   'has_value': False},
#  '3812': {'id': '3812', 'name': 'Miniature golf on site', 'has_value': False},
#  '3813': {'id': '3813', 'name': 'Golf lessons on site', 'has_value': False},
#  '1073744740': {'id': '1073744740',
#   'name': 'Wheelchair accessible – no',
#   'has_value': False},
#  '3825': {'id': '3825', 'name': 'Playground on site', 'has_value': False},
#  '3826': {'id': '3826',
#   'name': 'Racquetball/squash on site',
#   'has_value': False},
#  '3827': {'id': '3827', 'name': 'Rafting on site', 'has_value': False},
#  '3829': {'id': '3829',
#   'name': 'Rowing or canoeing on site',
#   'has_value': False},
#  '3820': {'id': '3820', 'name': 'Kayaking on site', 'has_value': False},
#  '2618': {'id': '2618', 'name': 'Tennis on site', 'has_value': False},
#  '3821': {'id': '3821', 'name': 'Motor boating on site', 'has_value': False},
#  '2617': {'id': '2617', 'name': 'Golf course on site', 'has_value': False},
#  '3822': {'id': '3822', 'name': 'Mountain biking on site', 'has_value': False},
#  '3823': {'id': '3823', 'name': 'Parasailing on site', 'has_value': False},
#  '3824': {'id': '3824', 'name': 'Pilates classes on site', 'has_value': False},
#  '1073742791': {'id': '1073742791',
#   'name': 'Newspapers in lobby (surcharge)',
#   'has_value': False},
#  '1073743884': {'id': '1073743884',
#   'name': 'Lockers available',
#   'has_value': False},
#  '1073743404': {'id': '1073743404',
#   'name': 'Shared microwave',
#   'has_value': False},
#  '1073743405': {'id': '1073743405',
#   'name': 'Shared refrigerator',
#   'has_value': False},
#  '3836': {'id': '3836', 'name': 'Ski lessons on site', 'has_value': False},
#  '3837': {'id': '3837',
#   'name': 'Cross-country skiing on site',
#   'has_value': False},
#  '3838': {'id': '3838', 'name': 'Downhill skiing on site', 'has_value': False},
#  '3839': {'id': '3839', 'name': 'Skydiving on site', 'has_value': False},
#  '3831': {'id': '3831', 'name': 'Sailing on site', 'has_value': False},
#  '3832': {'id': '3832',
#   'name': 'Scooter/moped rentals on site',
#   'has_value': False},
#  '3833': {'id': '3833', 'name': 'Scuba diving on site', 'has_value': False},
#  '3835': {'id': '3835',
#   'name': 'Ski equipment rentals on site',
#   'has_value': False},
#  '1073743877': {'id': '1073743877',
#   'name': 'Water dispenser',
#   'has_value': False},
#  '3969': {'id': '3969', 'name': 'Daily', 'has_value': False},
#  '3601': {'id': '3601', 'name': 'Turkish bath/Hammam', 'has_value': False},
#  '3840': {'id': '3840', 'name': 'Snorkeling on site', 'has_value': False},
#  '3842': {'id': '3842', 'name': 'Snowboarding on site', 'has_value': False},
#  '3843': {'id': '3843', 'name': 'Snowmobiling on site', 'has_value': False},
#  '3844': {'id': '3844', 'name': 'Snowshoeing on site', 'has_value': False},
#  '3846': {'id': '3846',
#   'name': 'Surfing/bodyboarding on site',
#   'has_value': False},
#  '1073744831': {'id': '1073744831',
#   'name': 'Change of bed sheets (on request)',
#   'has_value': False},
#  '1073744828': {'id': '1073744828',
#   'name': 'Change of towels (on request)',
#   'has_value': False},
#  '3850': {'id': '3850', 'name': 'Tennis lessons on site', 'has_value': False},
#  '3851': {'id': '3851', 'name': 'Volleyball on site', 'has_value': False},
#  '3852': {'id': '3852', 'name': 'Water skiing on site', 'has_value': False},
#  '4700': {'id': '4700',
#   'name': 'Supervised childcare/activities (surcharge)',
#   'has_value': False},
#  '3854': {'id': '3854', 'name': 'Windsurfing on site', 'has_value': False},
#  '3855': {'id': '3855',
#   'name': 'Yoga classes/instruction on site',
#   'has_value': False},
#  '2529': {'id': '2529',
#   'name': 'Area shuttle (surcharge)',
#   'has_value': False},
#  '2528': {'id': '2528', 'name': 'Free area shuttle', 'has_value': False},
#  '1073742765': {'id': '1073742765',
#   'name': 'Fitness facilities (surcharge)',
#   'has_value': False},
#  '1073744825': {'id': '1073744825',
#   'name': 'Lifeguard on site',
#   'has_value': False},
#  '1073742767': {'id': '1073742767',
#   'name': 'Hot tub (surcharge)',
#   'has_value': False},
#  '2537': {'id': '2537', 'name': 'Number of restaurants -', 'has_value': True},
#  '2416': {'id': '2416',
#   'name': 'Free train station pickup',
#   'has_value': False},
#  '3500': {'id': '3500', 'name': 'Snack bar/deli', 'has_value': False},
#  '3861': {'id': '3861', 'name': 'Free self parking', 'has_value': False},
#  '3862': {'id': '3862',
#   'name': 'Self parking (surcharge)',
#   'has_value': False},
#  '3863': {'id': '3863', 'name': 'Free valet parking', 'has_value': False},
#  '3864': {'id': '3864',
#   'name': 'Valet parking (surcharge)',
#   'has_value': False},
#  '3865': {'id': '3865', 'name': 'Computer station', 'has_value': False},
#  '2419': {'id': '2419',
#   'name': 'Wheelchair accessible path of travel',
#   'has_value': False},
#  '2539': {'id': '2539',
#   'name': 'Conference space size (feet) -',
#   'has_value': True},
#  '2538': {'id': '2538', 'name': '24-hour business center', 'has_value': False}}
